# %% [markdown]
# # Irony Detection in English Tweets

# %% [markdown]
# * João Dossena - UP201800174
# * João Rosário - UP201806334
# * João Sousa - UP201806613
#
# MIEIC, Class 8, Group 14

# %% [markdown]
# ## Project Specification

# %% [markdown]
# The project is made up of two subtasks.
# In the first one the objective is the detection of irony given a tweet in English, marking it out either with a value of 0 or 1 if irony is absent or not, respectively.
# In the second subtask the goal is to classify the type of irony into 4 classes:
# 1. verbal irony realized through a polarity contrast
# 2. verbal irony without such a polarity contrast (i.e., other verbal irony)
# 3. descriptions of situational irony
# 4. non-irony
#
# The datasets provided consisted of a set of entries where the first column was the tweet index, the second one was the label (either 0 or 1, or 0, 1, 2 or 3 depending on the task) in the case of the training data or the tweet text which corresponds to the third column in the training datasets.

# %% [markdown]
# ## Required Libraries
#
# * pandas
# * sklearn
# * re
# * nltk
# * imblearn
# * time
# * seaborn
# * matplotlib
# * numpy

# %% [markdown]
# # Task A

# %% [markdown]
# ## Exploratory Data Analysis

# %%
import pandas as pd
import numpy as np
import seaborn as sns #visualisation
import matplotlib.pyplot as plt #visualisation
# %matplotlib inline 
sns.set(color_codes=True)

# %%
# Get data from file
def readData(path_train, path_test):
    df = pd.read_csv(path_train, sep="\t")
    test_df = pd.read_csv(path_test, sep="\t")
    print("Data Read Successfully")
    return (df, test_df)

# %%
(train_df, test_df) = readData("../datasets/train/train-taskA.txt", "../datasets/test/gold_test_taskA.txt")
# Out:
# Data Read Successfully

# %%
train_df.shape
# Out:
# (3817, 3)

# %%
test_df.shape
# Out:
# (784, 3)

# %%
# checking if data was actually read correctly
train_df.head()
# Out:
#    Tweet index  Label                                         Tweet text
# 0            1      1  Sweet United Nations video. Just in time for C...
# 1            2      1  @mrdahl87 We are rumored to have talked to Erv...
# 2            3      1  Hey there! Nice to see you Minnesota/ND Winter...
# 3            4      0                3 episodes left I'm dying over here
# 4            5      1  I can't breathe! was chosen as the most notabl...

# %%
# checking if there are any null values present in the dataset
train_df.isnull().sum()
# Out:
# Tweet index    0
# Label          0
# Tweet text     0
# dtype: int64

# %%
print(train_df.groupby('Label')['Tweet text'].count())
train_df.groupby('Label')['Tweet text'].count().plot.bar(ylim=0)
plt.show()
# Out:
# Label
# 0    1916
# 1    1901
# Name: Tweet text, dtype: int64

# %% [markdown]
# The data appears to be balanced. There isn't a significant difference between the number of entries per label. Therefore over/undersampling doesn't seem to be needed.

# %% [markdown]
# ## Text processing

# %%
import re
import nltk
from nltk.stem.porter import PorterStemmer
from nltk.stem.lancaster import LancasterStemmer
from nltk.stem import WordNetLemmatizer
from nltk.corpus import stopwords
import numpy as np
from nltk.tokenize import word_tokenize
from nltk import pos_tag
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer
from sklearn.preprocessing import LabelEncoder
from collections import defaultdict
from nltk.corpus import wordnet as wn
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn import model_selection, naive_bayes, svm
from sklearn.metrics import accuracy_score


def processing(Corpus):
    # Step - a : Remove blank rows if any.
    Corpus['Tweet text'].dropna(inplace=True)
    
    # Step - b : Change all the text to lower case. This is required as python interprets 'dog' and 'DOG' differently
    Corpus['Tweet text'] = [entry.lower() for entry in Corpus['Tweet text']]
    
    # Step - c : @Usernames and links removed / Tokenization : each entry in the corpus will be broken into set of words
    Corpus['Tweet text'] = [re.sub('@[a-zA-Z0-9_]+|https?://t.co/[a-zA-Z0-9_]+|[^a-zA-Z]', ' ', entry) for entry in Corpus['Tweet text']]
    Corpus['Tweet text']= [word_tokenize(entry) for entry in Corpus['Tweet text']]
    
    # Step - d : Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting.
    # WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
    tag_map = defaultdict(lambda : wn.NOUN)
    tag_map['J'] = wn.ADJ
    tag_map['V'] = wn.VERB
    tag_map['R'] = wn.ADV
    for index,entry in enumerate(Corpus['Tweet text']):
        
        # Declaring Empty List to store the words that follow the rules for this step
        Final_words = []
        
        # Initializing WordNetLemmatizer()
        word_Lemmatized = WordNetLemmatizer()
        
        # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
        for word, tag in pos_tag(entry):
            # Below condition is to check for Stop words and consider only alphabets
            if word not in stopwords.words('english') and word.isalpha():
                word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
                Final_words.append(word_Final)
        # The final processed set of words for each iteration will be stored in 'text_final'
        Corpus.loc[index,'text_final'] = str(Final_words)
    
    print("Processed df")
    return Corpus

def processing_2(df):
    stemmer = LancasterStemmer()
    corpus = []
    for i in range(len(df)):
        
        # get tweet and remove usernames (@username) and links to pictures (https://t.co/link)
        tweet = re.sub('@[a-zA-Z0-9_]+|https?://t.co/[a-zA-Z0-9_]+|[^a-zA-Z]', ' ', df['Tweet text'][i])

        # to lower-case and tokenize
        tweet = tweet.lower().split()

        # Stemming and stop word removal
        stemmed_tweet = ' '.join([stemmer.stem(w) for w in tweet if not w in set(stopwords.words('english'))])
        corpus.append(stemmed_tweet)
    
    print("Processed df")
    return corpus

# %%
# train and test processing
corpus_2 = processing_2(train_df)
test_corpus_2 = processing_2(test_df)

corpus = processing(train_df)
test_corpus = processing(test_df)
# Out:
# Processed df
# Processed df
# Processed df
# Processed df

# %%
from sklearn.feature_extraction.text import CountVectorizer

# Create bag-of-words model
def bagOfWords(df, corpus):
    vectorizer = CountVectorizer(max_features = 1500) # original = 1500
    X = vectorizer.fit_transform(corpus).toarray()
    y = df.iloc[:,1].values

    return (X, y)

# %%
# Function that displays the confusion matrix
def plot_conf_matrix(Test_Y, y_pred):
    conf_matrix = confusion_matrix(y_true=Test_Y, y_pred=y_pred)
    fig, ax = plt.subplots(figsize=(7.5, 7.5))
    ax.matshow(conf_matrix, cmap=plt.cm.Blues, alpha=0.3)
    for i in range(conf_matrix.shape[0]):
        for j in range(conf_matrix.shape[1]):
            ax.text(x=j, y=i,s=conf_matrix[i, j], va='center', ha='center', size='xx-large')
    plt.xlabel('Predictions', fontsize=18)
    plt.ylabel('Actuals', fontsize=18)
    plt.title('Confusion Matrix', fontsize=18)
    plt.show()

# %%
Train_X = corpus['text_final']
Train_Y = corpus.iloc[:,1].values

Test_X = test_corpus['text_final']
Test_Y = test_corpus.iloc[:,1].values


(Train_X_2, Train_Y_2) = bagOfWords(train_df, corpus_2)
(Test_X_2, Test_Y_2) = bagOfWords(test_df, test_corpus_2)

# %%
# Word Vectorization
print("TfidfVectorizer max_features=5000")
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)
# Out:
# TfidfVectorizer max_features=5000

# %% [markdown]
# ## Algorithms and Parameter Tuning

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import f1_score

from sklearn.metrics import classification_report
from sklearn.model_selection import GridSearchCV

import time

# %% [markdown]
# ### Support Vector Machines

# %%
from sklearn.svm import SVC

# %%
# SVM default
def svm_default(X_train, X_test, y_train, y_test):
    
    print("SVM (default parameters)")
    classifier = SVC()
    return svm(classifier, X_train, X_test, y_train, y_test)

# SVM optimized (using parameter found by findSVC - function ahead)
def svm_optimized(X_train, X_test, y_train, y_test):
    
    print("SVM ('C': 1, 'kernel': 'sigmoid')")
    classifier = SVC(C=1, kernel='sigmoid')
    return svm(classifier, X_train, X_test, y_train, y_test)
    

# SVM
def svm(classifier, X_train, X_test, y_train, y_test):
    
    time_0 = time.time()
    classifier.fit(X_train, y_train)
    training_time = str(round(time.time()-time_0,3))
    
    time_1 = time.time()
    y_pred = classifier.predict(X_test)
    predict_time = str(round(time.time()-time_1,3))
    
    print("Training Time (seconds): " + training_time)
    print("Predict Time (seconds): " + predict_time)
    
    print(classification_report(y_test, y_pred))
    
    plot_conf_matrix(Test_Y, y_pred)
    
    return (classification_report(y_test, y_pred, output_dict=True), training_time, predict_time, y_test, y_pred)

# %%
# Using Lemmatization / Word Vectorization
(svc_optimized, svc_optimized_train_time, svc_optimized_predict_time, svc_optimized_y_test, svc_optimized_y_pred) = svm_optimized(Train_X_Tfidf, Test_X_Tfidf, Train_Y, Test_Y)
print("\n-----\n")
(svc_for_graph, svc_train_time, svc_predict_time, svc_y_test, svc_y_pred) = svm_default(Train_X_Tfidf, Test_X_Tfidf, Train_Y, Test_Y)
# Out:
# SVM ('C': 1, 'kernel': 'sigmoid')
# Training Time (seconds): 0.734
# Predict Time (seconds): 0.108
#               precision    recall  f1-score   support
#
#            0       0.72      0.64      0.67       473
#            1       0.53      0.61      0.57       311
#
#     accuracy                           0.63       784
#    macro avg       0.62      0.63      0.62       784
# weighted avg       0.64      0.63      0.63       784
# -----
#
# SVM (default parameters)
# Training Time (seconds): 0.837
# Predict Time (seconds): 0.148
#               precision    recall  f1-score   support
#
#            0       0.71      0.68      0.70       473
#            1       0.55      0.58      0.56       311
#
#     accuracy                           0.64       784
#    macro avg       0.63      0.63      0.63       784
# weighted avg       0.65      0.64      0.64       784

# %%
# Using Stemming / Bag-of-words
(svc_optimized, svc_optimized_train_time, svc_optimized_predict_time, svc_optimized_y_test, svc_optimized_y_pred) = svm_optimized(Train_X_2, Test_X_2, Train_Y_2, Test_Y_2)
print("\n-----\n")
(svc_for_graph, svc_train_time, svc_predict_time, svc_y_test, svc_y_pred) = svm_default(Train_X_2, Test_X_2, Train_Y_2, Test_Y_2)
# Out:
# SVM ('C': 1, 'kernel': 'sigmoid')
# Training Time (seconds): 8.429
# Predict Time (seconds): 1.527
#               precision    recall  f1-score   support
#
#            0       0.58      0.65      0.61       473
#            1       0.35      0.29      0.32       311
#
#     accuracy                           0.51       784
#    macro avg       0.47      0.47      0.47       784
# weighted avg       0.49      0.51      0.50       784
# -----
#
# SVM (default parameters)
# Training Time (seconds): 9.718
# Predict Time (seconds): 2.729
#               precision    recall  f1-score   support
#
#            0       0.59      0.77      0.66       473
#            1       0.34      0.18      0.23       311
#
#     accuracy                           0.53       784
#    macro avg       0.46      0.47      0.45       784
# weighted avg       0.49      0.53      0.49       784

# %%
# Using GridSearch to try to find the best parameters
def findSVC(X_train, X_test, y_train, y_test):

    tuned_parameters = {'kernel': ['linear', 'poly', 'sigmoid'],
                        'C': [0.5, 1.0, 2.0]
                    }

    clf = GridSearchCV(SVC(), tuned_parameters, n_jobs=-1, cv=3)
    clf.fit(X_train, y_train)

    print('Best parameters found:\n', clf.best_params_)

    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))

    y_true, y_pred = y_test , clf.predict(X_test)

    print('Results on the test set:')
    print(classification_report(y_true, y_pred))
    
    return classification_report(y_test, y_pred, output_dict=True)

# %%
svc_tunning_for_graph = findSVC(Train_X_Tfidf, Test_X_Tfidf, Train_Y, Test_Y)
# Out:
# Best parameters found:
#  {'C': 1.0, 'kernel': 'sigmoid'}
# 0.612 (+/-0.029) for {'C': 0.5, 'kernel': 'linear'}
# 0.511 (+/-0.008) for {'C': 0.5, 'kernel': 'poly'}
# 0.611 (+/-0.026) for {'C': 0.5, 'kernel': 'sigmoid'}
# 0.610 (+/-0.042) for {'C': 1.0, 'kernel': 'linear'}
# 0.596 (+/-0.024) for {'C': 1.0, 'kernel': 'poly'}
# 0.613 (+/-0.037) for {'C': 1.0, 'kernel': 'sigmoid'}
# 0.602 (+/-0.036) for {'C': 2.0, 'kernel': 'linear'}
# 0.595 (+/-0.014) for {'C': 2.0, 'kernel': 'poly'}
# 0.597 (+/-0.036) for {'C': 2.0, 'kernel': 'sigmoid'}
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.72      0.64      0.67       473
#            1       0.53      0.61      0.57       311
#
#     accuracy                           0.63       784
#    macro avg       0.62      0.63      0.62       784
# weighted avg       0.64      0.63      0.63       784

# %% [markdown]
# ### Linear Model - Perceptron

# %%
from sklearn.linear_model import Perceptron

# Perceptron
def perceptron(X_train, X_test, y_train, y_test):
    classifier = Perceptron()
    
    time_0 = time.time()
    classifier.fit(X_train, y_train)
    training_time = str(round(time.time()-time_0,5))
    
    time_1 = time.time()
    y_pred = classifier.predict(X_test)
    
    predict_time = str(round(time.time()-time_1,5))
    
    print("Training Time (seconds): " + training_time)
    print("Predict Time (seconds): " + predict_time)

    print(classification_report(y_test, y_pred))
    
    plot_conf_matrix(Test_Y, y_pred)
    
    return (classification_report(y_test, y_pred, output_dict=True), training_time, predict_time, y_test, y_pred)

# %%
(perceptron_default_for_graph, perceptron_train_time, perceptron_predict_time, perceptron_y_test, perceptron_y_pred) = perceptron(Train_X_Tfidf, Test_X_Tfidf, Train_Y, Test_Y)
# Out:
# Training Time (seconds): 0.01
# Predict Time (seconds): 0.0
#               precision    recall  f1-score   support
#
#            0       0.69      0.62      0.65       473
#            1       0.50      0.59      0.54       311
#
#     accuracy                           0.60       784
#    macro avg       0.60      0.60      0.60       784
# weighted avg       0.62      0.60      0.61       784

# %%
def findPerceptron(X_train, X_test, y_train, y_test):
    
    parameter_space = {
        'penalty': ['l2', 'l1', 'elasticnet'],
        'alpha': [0.05, 0.0001],
        'max_iter': [100, 200, 500, 1000, 2000],
    }

    clf = GridSearchCV(Perceptron(), parameter_space, n_jobs=-1, cv=3)
    clf.fit(X_train, y_train)

    # Best paramete set
    print('Best parameters found:\n', clf.best_params_)

    # All results
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))

    y_true, y_pred = y_test , clf.predict(X_test)

    print('Results on the test set:')
    print(classification_report(y_true, y_pred))
    
    return classification_report(y_test, y_pred, output_dict=True)

# %%
perceptron_tunning_for_graph = findPerceptron(Train_X_Tfidf, Test_X_Tfidf, Train_Y, Test_Y)
# Out:
# Best parameters found:
#  {'alpha': 0.0001, 'max_iter': 100, 'penalty': 'elasticnet'}
# 0.495 (+/-0.019) for {'alpha': 0.05, 'max_iter': 100, 'penalty': 'l2'}
# 0.500 (+/-0.004) for {'alpha': 0.05, 'max_iter': 100, 'penalty': 'l1'}
# 0.500 (+/-0.004) for {'alpha': 0.05, 'max_iter': 100, 'penalty': 'elasticnet'}
# 0.495 (+/-0.019) for {'alpha': 0.05, 'max_iter': 200, 'penalty': 'l2'}
# 0.500 (+/-0.004) for {'alpha': 0.05, 'max_iter': 200, 'penalty': 'l1'}
# 0.500 (+/-0.004) for {'alpha': 0.05, 'max_iter': 200, 'penalty': 'elasticnet'}
# 0.495 (+/-0.019) for {'alpha': 0.05, 'max_iter': 500, 'penalty': 'l2'}
# 0.500 (+/-0.004) for {'alpha': 0.05, 'max_iter': 500, 'penalty': 'l1'}
# 0.500 (+/-0.004) for {'alpha': 0.05, 'max_iter': 500, 'penalty': 'elasticnet'}
# 0.495 (+/-0.019) for {'alpha': 0.05, 'max_iter': 1000, 'penalty': 'l2'}
# 0.500 (+/-0.004) for {'alpha': 0.05, 'max_iter': 1000, 'penalty': 'l1'}
# 0.500 (+/-0.004) for {'alpha': 0.05, 'max_iter': 1000, 'penalty': 'elasticnet'}
# 0.495 (+/-0.019) for {'alpha': 0.05, 'max_iter': 2000, 'penalty': 'l2'}
# 0.500 (+/-0.004) for {'alpha': 0.05, 'max_iter': 2000, 'penalty': 'l1'}
# 0.500 (+/-0.004) for {'alpha': 0.05, 'max_iter': 2000, 'penalty': 'elasticnet'}
# 0.578 (+/-0.012) for {'alpha': 0.0001, 'max_iter': 100, 'penalty': 'l2'}
# 0.570 (+/-0.032) for {'alpha': 0.0001, 'max_iter': 100, 'penalty': 'l1'}
# 0.581 (+/-0.029) for {'alpha': 0.0001, 'max_iter': 100, 'penalty': 'elasticnet'}
# 0.578 (+/-0.012) for {'alpha': 0.0001, 'max_iter': 200, 'penalty': 'l2'}
# 0.570 (+/-0.032) for {'alpha': 0.0001, 'max_iter': 200, 'penalty': 'l1'}
# 0.581 (+/-0.029) for {'alpha': 0.0001, 'max_iter': 200, 'penalty': 'elasticnet'}
# 0.578 (+/-0.012) for {'alpha': 0.0001, 'max_iter': 500, 'penalty': 'l2'}
# 0.570 (+/-0.032) for {'alpha': 0.0001, 'max_iter': 500, 'penalty': 'l1'}
# 0.581 (+/-0.029) for {'alpha': 0.0001, 'max_iter': 500, 'penalty': 'elasticnet'}
# 0.578 (+/-0.012) for {'alpha': 0.0001, 'max_iter': 1000, 'penalty': 'l2'}
# 0.570 (+/-0.032) for {'alpha': 0.0001, 'max_iter': 1000, 'penalty': 'l1'}
# 0.581 (+/-0.029) for {'alpha': 0.0001, 'max_iter': 1000, 'penalty': 'elasticnet'}
# 0.578 (+/-0.012) for {'alpha': 0.0001, 'max_iter': 2000, 'penalty': 'l2'}
# 0.570 (+/-0.032) for {'alpha': 0.0001, 'max_iter': 2000, 'penalty': 'l1'}
# 0.581 (+/-0.029) for {'alpha': 0.0001, 'max_iter': 2000, 'penalty': 'elasticnet'}
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.74      0.51      0.60       473
#            1       0.49      0.72      0.59       311
#
#     accuracy                           0.60       784
#    macro avg       0.62      0.62      0.60       784
# weighted avg       0.64      0.60      0.60       784

# %% [markdown]
# ### Neural Networks

# %%
from sklearn.neural_network import MLPClassifier

# %%
# Multi Layered Perceptron
def mlp(X_train, X_test, y_train, y_test):
    
    classifier = MLPClassifier()
    time_0 = time.time()
    classifier.fit(X_train, y_train)
    training_time = str(round(time.time()-time_0,5))
    
    time_1 = time.time()
    y_pred = classifier.predict(X_test)
    predict_time = str(round(time.time()-time_1,5))
    
    print("Training Time (seconds): " + training_time)
    print("Predict Time (seconds): " + predict_time)
    
    print(classification_report(y_test, y_pred))
    
    plot_conf_matrix(Test_Y, y_pred)
    
    return (classification_report(y_test, y_pred, output_dict=True), training_time, predict_time, y_test, y_pred)

# %%
(mlp_default_for_graph, mlp_train_time, mlp_predict_time, mlp_y_test, mlp_y_pred) = mlp(Train_X_Tfidf, Test_X_Tfidf, Train_Y, Test_Y)
# Out:
# Training Time (seconds): 64.54635
# Predict Time (seconds): 0.001
#               precision    recall  f1-score   support
#
#            0       0.72      0.61      0.66       473
#            1       0.52      0.64      0.57       311
#
#     accuracy                           0.62       784
#    macro avg       0.62      0.62      0.62       784
# weighted avg       0.64      0.62      0.62       784

# %%
# Finding the best parameters for MLP
def findMlp(X_train, X_test, y_train, y_test):
    
    parameter_space = {
        'hidden_layer_sizes': [(20,20), (50,50), (50,50,50), (10,10), (100)],
        'activation': ['identity', 'logistic', 'tanh', 'relu'],
        'solver': ['sgd'],
        'alpha': [0.05, 0.0001],
        'learning_rate': ['constant', 'invscaling', 'adaptive'],
        'max_iter': [100, 200, 500],
    }

    clf = GridSearchCV(MLPClassifier(), parameter_space, n_jobs=-1, cv=3)
    clf.fit(X_train, y_train)

    # Best paramete set
    print('Best parameters found:\n', clf.best_params_)

    # All results
    means = clf.cv_results_['mean_test_score']
    stds = clf.cv_results_['std_test_score']
    for mean, std, params in zip(means, stds, clf.cv_results_['params']):
        print("%0.3f (+/-%0.03f) for %r" % (mean, std * 2, params))

    y_true, y_pred = y_test , clf.predict(X_test)

    print('Results on the test set:')
    print(classification_report(y_true, y_pred))
    
    return classification_report(y_test, y_pred, output_dict=True)

# %%
mlp_tunning_for_graph = findMlp(Train_X_Tfidf, Test_X_Tfidf, Train_Y, Test_Y)
# Out:
# Best parameters found:
#  {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.513 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.497 (+/-0.033) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.529 (+/-0.020) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.504 (+/-0.007) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.512 (+/-0.018) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.518 (+/-0.033) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.524 (+/-0.013) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.516 (+/-0.023) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.525 (+/-0.044) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.521 (+/-0.025) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.514 (+/-0.035) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.554 (+/-0.046) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.521 (+/-0.007) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.516 (+/-0.016) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.516 (+/-0.025) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.516 (+/-0.016) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.498 (+/-0.007) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.512 (+/-0.024) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.520 (+/-0.001) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.513 (+/-0.012) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.520 (+/-0.085) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.510 (+/-0.011) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.527 (+/-0.009) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.498 (+/-0.001) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.516 (+/-0.021) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.528 (+/-0.049) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.520 (+/-0.009) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.508 (+/-0.011) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.496 (+/-0.037) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.524 (+/-0.032) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.006) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.010) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.512 (+/-0.027) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.525 (+/-0.031) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.524 (+/-0.019) for {'activation': 'identity', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.507 (+/-0.014) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.494 (+/-0.023) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.521 (+/-0.034) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.500 (+/-0.008) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.005) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.521 (+/-0.047) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.550 (+/-0.049) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.526 (+/-0.025) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.495 (+/-0.037) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.512 (+/-0.028) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.044) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.508 (+/-0.028) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.518 (+/-0.035) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.506 (+/-0.042) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.524 (+/-0.021) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.515 (+/-0.020) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.509 (+/-0.028) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.553 (+/-0.111) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.010) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.529 (+/-0.017) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.513 (+/-0.021) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.544 (+/-0.084) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.505 (+/-0.029) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.009) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.552 (+/-0.081) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.503 (+/-0.009) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.517 (+/-0.047) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.516 (+/-0.023) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.516 (+/-0.016) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.518 (+/-0.038) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.527 (+/-0.011) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.504 (+/-0.021) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.005) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.503 (+/-0.007) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.510 (+/-0.030) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.531 (+/-0.013) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.039) for {'activation': 'identity', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.498 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.005) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.498 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.003) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.005) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.002) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.504 (+/-0.007) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.498 (+/-0.010) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.002) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.504 (+/-0.006) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.498 (+/-0.014) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.000) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'logistic', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.503 (+/-0.043) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.512 (+/-0.032) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.518 (+/-0.027) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.513 (+/-0.026) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.522 (+/-0.018) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.517 (+/-0.019) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.510 (+/-0.017) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.517 (+/-0.046) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.514 (+/-0.012) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.492 (+/-0.013) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.520 (+/-0.018) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.499 (+/-0.016) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.507 (+/-0.027) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.549 (+/-0.089) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.505 (+/-0.021) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.003) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.499 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.498 (+/-0.001) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.507 (+/-0.020) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.524 (+/-0.033) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.517 (+/-0.033) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.011) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.527 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.507 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.518 (+/-0.013) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.520 (+/-0.008) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.507 (+/-0.009) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.503 (+/-0.044) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.527 (+/-0.033) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.522 (+/-0.050) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.005) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.495 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.518 (+/-0.014) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.519 (+/-0.023) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.527 (+/-0.028) for {'activation': 'tanh', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.513 (+/-0.028) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.495 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.518 (+/-0.011) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.503 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.498 (+/-0.001) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.517 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.508 (+/-0.025) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.530 (+/-0.013) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.498 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.525 (+/-0.002) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.511 (+/-0.011) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.498 (+/-0.001) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.498 (+/-0.006) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.516 (+/-0.018) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.520 (+/-0.007) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.510 (+/-0.038) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.522 (+/-0.017) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.520 (+/-0.035) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.513 (+/-0.021) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.498 (+/-0.001) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.497 (+/-0.012) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.003) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.508 (+/-0.034) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.513 (+/-0.028) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.507 (+/-0.049) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.504 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.028) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.523 (+/-0.037) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.521 (+/-0.040) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.510 (+/-0.030) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.512 (+/-0.014) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.525 (+/-0.027) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.510 (+/-0.008) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.506 (+/-0.017) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.505 (+/-0.018) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.532 (+/-0.018) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.508 (+/-0.041) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.504 (+/-0.043) for {'activation': 'tanh', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.007) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.509 (+/-0.017) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.507 (+/-0.016) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.507 (+/-0.010) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.504 (+/-0.011) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.509 (+/-0.012) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.005) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.006) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.510 (+/-0.017) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.502 (+/-0.007) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.005) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.510 (+/-0.011) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.509 (+/-0.025) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.012) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.497 (+/-0.014) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.511 (+/-0.014) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.007) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.491 (+/-0.018) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.506 (+/-0.026) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.518 (+/-0.029) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.512 (+/-0.020) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.496 (+/-0.015) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.502 (+/-0.007) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.012) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.496 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.507 (+/-0.020) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.505 (+/-0.022) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.505 (+/-0.025) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.000) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.009) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.491 (+/-0.025) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.499 (+/-0.003) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.495 (+/-0.015) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.506 (+/-0.021) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.496 (+/-0.010) for {'activation': 'relu', 'alpha': 0.05, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.510 (+/-0.020) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.496 (+/-0.016) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.001) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.006) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.499 (+/-0.005) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.510 (+/-0.015) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.494 (+/-0.012) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.504 (+/-0.005) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (20, 20), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.505 (+/-0.013) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.513 (+/-0.027) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.513 (+/-0.026) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.008) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.505 (+/-0.007) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.511 (+/-0.018) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.510 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.507 (+/-0.015) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.511 (+/-0.018) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.494 (+/-0.027) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.498 (+/-0.001) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.498 (+/-0.001) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.497 (+/-0.007) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.516 (+/-0.041) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.498 (+/-0.015) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.010) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (50, 50, 50), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.498 (+/-0.008) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.500 (+/-0.005) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.499 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.500 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.502 (+/-0.001) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.513 (+/-0.023) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.501 (+/-0.009) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': (10, 10), 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.001) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 100, 'solver': 'sgd'}
# 0.505 (+/-0.006) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 200, 'solver': 'sgd'}
# 0.512 (+/-0.014) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'constant', 'max_iter': 500, 'solver': 'sgd'}
# 0.497 (+/-0.002) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 100, 'solver': 'sgd'}
# 0.501 (+/-0.004) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 200, 'solver': 'sgd'}
# 0.497 (+/-0.013) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'invscaling', 'max_iter': 500, 'solver': 'sgd'}
# 0.501 (+/-0.007) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 100, 'solver': 'sgd'}
# 0.511 (+/-0.034) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 200, 'solver': 'sgd'}
# 0.505 (+/-0.012) for {'activation': 'relu', 'alpha': 0.0001, 'hidden_layer_sizes': 100, 'learning_rate': 'adaptive', 'max_iter': 500, 'solver': 'sgd'}
# Results on the test set:
#               precision    recall  f1-score   support
#
#            0       0.65      0.60      0.62       473
#            1       0.45      0.50      0.47       311
#
#     accuracy                           0.56       784
#    macro avg       0.55      0.55      0.55       784
# weighted avg       0.57      0.56      0.56       784

# %% [markdown]
# ### Comparisons between Algorithms

# %%
import matplotlib.patches as mpatches

# %%
data = [
            [svc_for_graph['accuracy'], perceptron_default_for_graph['accuracy'], mlp_default_for_graph['accuracy']],
            [svc_tunning_for_graph['accuracy'], perceptron_tunning_for_graph['accuracy'], mlp_tunning_for_graph['accuracy']]
       ]

X = np.arange(3)
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1.5])
ax.bar(X + 0.0, data[0], color = '#3275a8', width = 0.25, tick_label=['SVM', 'Perceptron', 'MLP'])
ax.bar(X + 0.25, data[1], color = '#258f3c', width = 0.25)

plt.xticks([0.125,1.125,2.125], ['SVM', 'Perceptron', 'MLP'])

default_patch = mpatches.Patch(color='#3275a8', label='Default Algorithm')
tunned_patch = mpatches.Patch(color='#258f3c', label='GridSearch Tuned')
plt.legend(handles=[default_patch, tunned_patch], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.xlabel("Algorithm")
plt.ylabel("Accuracy")
plt.title("Accuracy obtained by each algorithm")

print()

# %%
data = [
            [float(svc_train_time), float(perceptron_train_time), float(mlp_train_time)]
       ]

X = np.arange(3)
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1.5])
ax.bar(X, data[0], color = '#3275a8', width = 0.25, tick_label=['SVM', 'Perceptron', 'MLP'])

default_patch = mpatches.Patch(color='#3275a8', label='Time')
plt.legend(handles=[default_patch], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.xlabel("Algorithm")
plt.ylabel("Training Time (s)")
plt.title("Training Time for each algorithm")

print()

# %%
data = [
            [float(svc_predict_time), float(perceptron_predict_time), float(mlp_predict_time)]
       ]

X = np.arange(3)
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1.5])
ax.bar(X, data[0], color = '#3275a8', width = 0.25, tick_label=['SVM', 'Perceptron', 'MLP'])

default_patch = mpatches.Patch(color='#3275a8', label='Time')
plt.legend(handles=[default_patch], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.xlabel("Algorithm")
plt.ylabel("Prediction Time (s)")
plt.title("Prediction Time for each algorithm")

print()

# %%
data = [
            [accuracy_score(svc_y_test, svc_y_pred), accuracy_score(perceptron_y_test, perceptron_y_pred), accuracy_score(mlp_y_test, mlp_y_pred)],
            [precision_score(svc_y_test, svc_y_pred), precision_score(perceptron_y_test, perceptron_y_pred), precision_score(mlp_y_test, mlp_y_pred)],
            [recall_score(svc_y_test, svc_y_pred), recall_score(perceptron_y_test, perceptron_y_pred), recall_score(mlp_y_test, mlp_y_pred)],
            [f1_score(svc_y_test, svc_y_pred), f1_score(perceptron_y_test, perceptron_y_pred), f1_score(mlp_y_test, mlp_y_pred)]
       ]

X = np.arange(3)
fig = plt.figure()
ax = fig.add_axes([0,0,1.5,1.5])
ax.bar(X + 0.0, data[0], color = '#3275a8', width = 0.2)
ax.bar(X + 0.2, data[1], color = '#258f3c', width = 0.2)
ax.bar(X + 0.40, data[2], color = '#d1682c', width = 0.2)
ax.bar(X + 0.6, data[3], color = '#9fd12c', width = 0.2)

plt.xticks([0.25,1.25,2.25], ['SVM', 'Perceptron', 'MLP'])

default_patch = mpatches.Patch(color='#3275a8', label='Accuracy')
tunned_patch = mpatches.Patch(color='#258f3c', label='Precision')
tunned_patch_2 = mpatches.Patch(color='#d1682c', label='Recall')
tunned_patch_3 = mpatches.Patch(color='#9fd12c', label='F1')
plt.legend(handles=[default_patch, tunned_patch, tunned_patch_2, tunned_patch_3], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

plt.xlabel("Algorithm")
plt.ylabel("Score")
plt.title("Scores obtained by each algorithm")

print()

# %% [markdown]
# # Task B

# %% [markdown]
# ## Exploratory Data Analysis

# %%
(train_df, test_df) = readData("../datasets/train/train-taskB.txt", "../datasets/test/gold_test_taskB.txt")
# Out:
# Data Read Successfully

# %%
train_df.shape
# Out:
# (3817, 3)

# %%
test_df.shape
# Out:
# (784, 3)

# %%
train_df.head()
# Out:
#    Tweet Index  Label                                         Tweet text
# 0            1      1  Sweet United Nations video. Just in time for C...
# 1            2      1  @mrdahl87 We are rumored to have talked to Erv...
# 2            3      1  Hey there! Nice to see you Minnesota/ND Winter...
# 3            4      0                3 episodes left I'm dying over here
# 4            5      2  I can't breathe! was chosen as the most notabl...

# %%
# checking if there are any null values present in the dataset
train_df.isnull().sum()
# Out:
# Tweet Index    0
# Label          0
# Tweet text     0
# dtype: int64

# %%
train_df.groupby('Label')['Tweet text'].count()
train_df.groupby('Label')['Tweet text'].count().plot.bar(ylim=0)
plt.show()

# %% [markdown]
# There isn't an uniform number of entries across all possible labels. The dataset is unbalanced. Therefore, we will try under/oversampling.

# %% [markdown]
# ## Text Processing

# %%
def processing(Corpus):
    # Step - a : Remove blank rows if any.
    Corpus['Tweet text'].dropna(inplace=True)
    
    # Step - b : Change all the text to lower case. This is required as python interprets 'dog' and 'DOG' differently
    Corpus['Tweet text'] = [entry.lower() for entry in Corpus['Tweet text']]
    
    # Step - c : Remove usernames / links / Tokenization : In this each entry in the corpus will be broken into set of words
    Corpus['Tweet text'] = [re.sub('@[a-zA-Z0-9_]+|https?://t.co/[a-zA-Z0-9_]+|[^a-zA-Z]', ' ', entry) for entry in Corpus['Tweet text']]
    Corpus['Tweet text']= [word_tokenize(entry) for entry in Corpus['Tweet text']]
    
    # Step - d : Remove Stop words, Non-Numeric and perfom Word Stemming/Lemmenting.# WordNetLemmatizer requires Pos tags to understand if the word is noun or verb or adjective etc. By default it is set to Noun
    tag_map = defaultdict(lambda : wn.NOUN)
    tag_map['J'] = wn.ADJ
    tag_map['V'] = wn.VERB
    tag_map['R'] = wn.ADV
    for index,entry in enumerate(Corpus['Tweet text']):
        
        # Declaring Empty List to store the words that follow the rules for this step
        Final_words = []
        
        # Initializing WordNetLemmatizer()
        word_Lemmatized = WordNetLemmatizer()
        
        # pos_tag function below will provide the 'tag' i.e if the word is Noun(N) or Verb(V) or something else.
        for word, tag in pos_tag(entry):
            # Below condition is to check for Stop words and consider only alphabets
            if word not in stopwords.words('english') and word.isalpha():
                word_Final = word_Lemmatized.lemmatize(word,tag_map[tag[0]])
                Final_words.append(word_Final)
        # The final processed set of words for each iteration will be stored in 'text_final'
        Corpus.loc[index,'text_final'] = str(Final_words)
    
    print("Processed")
    return Corpus

# %%
corpus = processing(train_df)
test_corpus = processing(test_df)
# Out:
# Processed
# Processed

# %%
from imblearn.under_sampling import RandomUnderSampler
from imblearn.over_sampling import RandomOverSampler
from imblearn.over_sampling import SMOTE
from collections import Counter
from matplotlib import pyplot

# %%
def smote(X_train, y_train):

    sm = SMOTE()
    X_train, y_train = sm.fit_resample(X_train, y_train)

    return (X_train, y_train)

# %%
Train_X = corpus['text_final']
Train_Y = corpus.iloc[:,1].values

Test_X = test_corpus['text_final']
Test_Y = test_corpus.iloc[:,1].values

# %%
# Word Vectorization
print("TfidfVectorizer max_features=5000")
Tfidf_vect = TfidfVectorizer(max_features=5000)
Tfidf_vect.fit(corpus['text_final'])
Train_X_Tfidf = Tfidf_vect.transform(Train_X)
Test_X_Tfidf = Tfidf_vect.transform(Test_X)
# Out:
# TfidfVectorizer max_features=5000

# %%
# Oversampling - Random Over Sampler
oversample = RandomOverSampler(sampling_strategy='all')
(Train_X_Tfidf_RandOS, Train_Y_RandOS) = oversample.fit_resample(Train_X_Tfidf, Train_Y)

counter = Counter(Train_Y_RandOS)
for k,v in counter.items():
    per = v / len(Train_Y) * 100
    print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
pyplot.title("Random Over Sampler")
pyplot.bar(counter.keys(), counter.values())
pyplot.xticks([0,1,2,3])
pyplot.show()
# Out:
# Class=1, n=1916 (50.196%)
# Class=0, n=1916 (50.196%)
# Class=2, n=1916 (50.196%)
# Class=3, n=1916 (50.196%)

# %%
# Oversampling - SMOTE
(Train_X_Tfidf_SMOTE, Train_Y_SMOTE) = smote(Train_X_Tfidf, Train_Y)

counter = Counter(Train_Y_SMOTE)
for k,v in counter.items():
    per = v / len(Train_Y) * 100
    print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
pyplot.title("SMOTE")
pyplot.bar(counter.keys(), counter.values())
pyplot.xticks([0,1,2,3])
pyplot.show()
# Out:
# Class=1, n=1916 (50.196%)
# Class=0, n=1916 (50.196%)
# Class=2, n=1916 (50.196%)
# Class=3, n=1916 (50.196%)

# %% [markdown]
# Due to the fact that by using SMOTE we got the same or even slightly worse results as the ones using RandomOverSampler, we decided to omit it past this point.

# %%
# Undersampling - Random Under Sampler
undersample = RandomUnderSampler()
(Train_X_Tfidf_RandUS, Train_Y_RandUS) = undersample.fit_resample(Train_X_Tfidf, Train_Y)

counter = Counter(Train_Y_RandUS)
for k,v in counter.items():
    per = v / len(Train_Y) * 100
    print('Class=%d, n=%d (%.3f%%)' % (k, v, per))
pyplot.title("Random Under Sampler")
pyplot.bar(counter.keys(), counter.values())
pyplot.xticks([0,1,2,3])
pyplot.show()
# Out:
# Class=0, n=202 (5.292%)
# Class=1, n=202 (5.292%)
# Class=2, n=202 (5.292%)
# Class=3, n=202 (5.292%)

# %% [markdown]
# ### Algorithms

# %%
# SVM
def svm(X_train, X_test, y_train, y_test):
    classifier = SVC()

    time_0 = time.time()
    classifier.fit(X_train, y_train)
    training_time = str(round(time.time()-time_0,3))
    
    time_1 = time.time()
    y_pred = classifier.predict(X_test)
    predict_time = str(round(time.time()-time_1,3))
    
    print("Training Time (seconds): " + training_time)
    print("Predict Time (seconds): " + predict_time)
    
    print(classification_report(y_test, y_pred, zero_division=0))
    
    plot_conf_matrix(Test_Y, y_pred)

    return (classification_report(y_test, y_pred, output_dict=True, zero_division=0), training_time, predict_time, y_test, y_pred)

# %%
(svc_for_graph_default, svc_train_time_default, svc_predict_time_default, svc_y_test_default, svc_y_pred_default) = svm(Train_X_Tfidf, Test_X_Tfidf, Train_Y, Test_Y)
# Out:
# Training Time (seconds): 1.419
# Predict Time (seconds): 0.154
#               precision    recall  f1-score   support
#
#            0       0.65      0.89      0.75       473
#            1       0.57      0.47      0.51       164
#            2       0.00      0.00      0.00        85
#            3       0.00      0.00      0.00        62
#
#     accuracy                           0.64       784
#    macro avg       0.30      0.34      0.32       784
# weighted avg       0.51      0.64      0.56       784

# %%
# Random Oversampling
(svc_for_graph_os, svc_train_time_os, svc_predict_time_os, svc_y_test_os, svc_y_pred_os) = svm(Train_X_Tfidf_RandOS, Test_X_Tfidf, Train_Y_RandOS, Test_Y)
# Out:
# Training Time (seconds): 3.079
# Predict Time (seconds): 0.209
#               precision    recall  f1-score   support
#
#            0       0.66      0.84      0.74       473
#            1       0.52      0.53      0.53       164
#            2       0.53      0.09      0.16        85
#            3       0.25      0.02      0.03        62
#
#     accuracy                           0.63       784
#    macro avg       0.49      0.37      0.36       784
# weighted avg       0.59      0.63      0.58       784

# %%
# Random Undersampling
(svc_for_graph_us, svc_train_time_us, svc_predict_time_us, svc_y_test_us, svc_y_pred_us) = svm(Train_X_Tfidf_RandUS, Test_X_Tfidf, Train_Y_RandUS, Test_Y)
# Out:
# Training Time (seconds): 0.055
# Predict Time (seconds): 0.033
#               precision    recall  f1-score   support
#
#            0       0.69      0.29      0.41       473
#            1       0.50      0.43      0.46       164
#            2       0.19      0.58      0.28        85
#            3       0.08      0.24      0.12        62
#
#     accuracy                           0.35       784
#    macro avg       0.37      0.38      0.32       784
# weighted avg       0.55      0.35      0.39       784

# %%
from sklearn.linear_model import Perceptron

# Perceptron
def perceptron(X_train, X_test, y_train, y_test):
    classifier = Perceptron()
    
    time_0 = time.time()
    classifier.fit(X_train, y_train)
    training_time = str(round(time.time()-time_0,5))
    
    time_1 = time.time()
    y_pred = classifier.predict(X_test)
    
    predict_time = str(round(time.time()-time_1,5))
    
    print("Training Time (seconds): " + training_time)
    print("Predict Time (seconds): " + predict_time)

    print(classification_report(y_test, y_pred))
    
    plot_conf_matrix(Test_Y, y_pred)
    
    return (classification_report(y_test, y_pred, output_dict=True), training_time, predict_time, y_test, y_pred)

# %%
(perceptron_for_graph_default, perceptron_train_time_default, perceptron_predict_time_default, perceptron_y_test_default, perceptron_y_pred_default) = perceptron(Train_X_Tfidf, Test_X_Tfidf, Train_Y, Test_Y)
# Out:
# Training Time (seconds): 0.01395
# Predict Time (seconds): 0.001
#               precision    recall  f1-score   support
#
#            0       0.72      0.59      0.65       473
#            1       0.38      0.60      0.46       164
#            2       0.33      0.38      0.35        85
#            3       0.06      0.03      0.04        62
#
#     accuracy                           0.53       784
#    macro avg       0.37      0.40      0.38       784
# weighted avg       0.55      0.53      0.53       784

# %%
# Random Oversampling
(perceptron_for_graph_os, perceptron_train_time_os, perceptron_predict_time_os, perceptron_y_test_os, perceptron_y_pred_os) = perceptron(Train_X_Tfidf_RandOS, Test_X_Tfidf, Train_Y_RandOS, Test_Y)
# Out:
# Training Time (seconds): 0.02
# Predict Time (seconds): 0.001
#               precision    recall  f1-score   support
#
#            0       0.70      0.58      0.64       473
#            1       0.34      0.52      0.41       164
#            2       0.27      0.29      0.28        85
#            3       0.15      0.11      0.13        62
#
#     accuracy                           0.50       784
#    macro avg       0.37      0.38      0.36       784
# weighted avg       0.54      0.50      0.51       784

# %%
# Random Undersampling
(perceptron_for_graph_us, perceptron_train_time_us, perceptron_predict_time_us, perceptron_y_test_us, perceptron_y_pred_us) = perceptron(Train_X_Tfidf_RandUS, Test_X_Tfidf, Train_Y_RandUS, Test_Y)
# Out:
# Training Time (seconds): 0.005
# Predict Time (seconds): 0.0
#               precision    recall  f1-score   support
#
#            0       0.68      0.31      0.42       473
#            1       0.39      0.41      0.40       164
#            2       0.14      0.31      0.19        85
#            3       0.08      0.27      0.12        62
#
#     accuracy                           0.33       784
#    macro avg       0.32      0.32      0.28       784
# weighted avg       0.51      0.33      0.37       784

# %%
from sklearn.neural_network import MLPClassifier

# Multi Layered Perceptron
def mlp(X_train, X_test, y_train, y_test):
    
    classifier = MLPClassifier(activation='tanh', alpha=0.05, hidden_layer_sizes=(7,), learning_rate='adaptive', solver='sgd')
    
    time_0 = time.time()
    classifier.fit(X_train, y_train)
    training_time = str(round(time.time()-time_0,5))
    
    time_1 = time.time()
    y_pred = classifier.predict(X_test)
    predict_time = str(round(time.time()-time_1,5))
    
    print("Training Time (seconds): " + training_time)
    print("Predict Time (seconds): " + predict_time)
    
    print(classification_report(y_test, y_pred, zero_division=0))
    
    plot_conf_matrix(Test_Y, y_pred)
    
    return (classification_report(y_test, y_pred, output_dict=True, zero_division=0), training_time, predict_time, y_test, y_pred)

# %%
(mlp_for_graph_default, mlp_train_time_default, mlp_predict_time_default, mlp_y_test_default, mlp_y_pred_default) = mlp(Train_X_Tfidf, Test_X_Tfidf, Train_Y, Test_Y)
# Out:
# Training Time (seconds): 2.93454
# Predict Time (seconds): 0.001
#               precision    recall  f1-score   support
#
#            0       0.61      1.00      0.76       473
#            1       1.00      0.04      0.07       164
#            2       0.00      0.00      0.00        85
#            3       0.00      0.00      0.00        62
#
#     accuracy                           0.61       784
#    macro avg       0.40      0.26      0.21       784
# weighted avg       0.58      0.61      0.47       784
# C:\Users\João António Sousa\AppData\Roaming\Python\Python38\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Random Oversampling
(mlp_for_graph_os, mlp_train_time_os, mlp_predict_time_os, mlp_y_test_os, mlp_y_pred_os) = mlp(Train_X_Tfidf_RandOS, Test_X_Tfidf, Train_Y_RandOS, Test_Y)
# Out:
# Training Time (seconds): 5.71035
# Predict Time (seconds): 0.001
#               precision    recall  f1-score   support
#
#            0       0.75      0.06      0.12       473
#            1       0.39      0.65      0.49       164
#            2       0.21      0.67      0.31        85
#            3       0.08      0.26      0.13        62
#
#     accuracy                           0.27       784
#    macro avg       0.36      0.41      0.26       784
# weighted avg       0.56      0.27      0.22       784
# C:\Users\João António Sousa\AppData\Roaming\Python\Python38\site-packages\sklearn\neural_network\_multilayer_perceptron.py:614: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
# Random Undersampling
(mlp_for_graph_us, mlp_train_time_us, mlp_predict_time_us, mlp_y_test_us, mlp_y_pred_us) = mlp(Train_X_Tfidf_RandUS, Test_X_Tfidf, Train_Y_RandUS, Test_Y)
# Out:
# Training Time (seconds): 0.66302
# Predict Time (seconds): 0.0
#               precision    recall  f1-score   support
#
#            0       0.66      0.63      0.64       473
#            1       0.27      0.45      0.34       164
#            2       0.00      0.00      0.00        85
#            3       0.04      0.03      0.04        62
#
#     accuracy                           0.48       784
#    macro avg       0.24      0.28      0.25       784
# weighted avg       0.45      0.48      0.46       784

# %% [markdown]
# ### Comparisons between Algorithms

# %%
import matplotlib.patches as mpatches

# %%
def plotComparisons(data, title):
    X = np.arange(3)
    fig = plt.figure()
    ax = fig.add_axes([0,0,1.5,1.5])
    ax.bar(X + 0.0, data[0], color = '#3275a8', width = 0.2)
    ax.bar(X + 0.2, data[1], color = '#258f3c', width = 0.2)
    ax.bar(X + 0.40, data[2], color = '#d1682c', width = 0.2)
    ax.bar(X + 0.6, data[3], color = '#9fd12c', width = 0.2)

    plt.xticks([0.25,1.25,2.25], ['SVM', 'Perceptron', 'Tuned MLP'])

    default_patch = mpatches.Patch(color='#3275a8', label='Accuracy')
    tunned_patch = mpatches.Patch(color='#258f3c', label='Precision')
    tunned_patch_2 = mpatches.Patch(color='#d1682c', label='Recall')
    tunned_patch_3 = mpatches.Patch(color='#9fd12c', label='F1')
    plt.legend(handles=[default_patch, tunned_patch, tunned_patch_2, tunned_patch_3], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.xlabel("Algorithm")
    plt.ylabel("Score")
    plt.title(title)

    print()

# %%
data = [
            [accuracy_score(svc_y_test_default, svc_y_pred_default), accuracy_score(perceptron_y_test_default, perceptron_y_pred_default), accuracy_score(mlp_y_test_default, mlp_y_pred_default)],
            [precision_score(svc_y_test_default, svc_y_pred_default, average='weighted', zero_division=0), precision_score(perceptron_y_test_default, perceptron_y_pred_default, average='weighted', zero_division=0), precision_score(mlp_y_test_default, mlp_y_pred_default, average='weighted', zero_division=0)],
            [recall_score(svc_y_test_default, svc_y_pred_default, average='weighted'), recall_score(perceptron_y_test_default, perceptron_y_pred_default, average='weighted'), recall_score(mlp_y_test_default, mlp_y_pred_default, average='weighted')],
            [f1_score(svc_y_test_default, svc_y_pred_default, average='weighted'), f1_score(perceptron_y_test_default, perceptron_y_pred_default, average='weighted'), f1_score(mlp_y_test_default, mlp_y_pred_default, average='weighted')]
       ]
title = "Scores obtained using Default Dataset"
plotComparisons(data, title)

# %%
data = [
            [accuracy_score(svc_y_test_os, svc_y_pred_os), accuracy_score(perceptron_y_test_os, perceptron_y_pred_os), accuracy_score(mlp_y_test_os, mlp_y_pred_os)],
            [precision_score(svc_y_test_os, svc_y_pred_os, average='weighted', zero_division=0), precision_score(perceptron_y_test_os, perceptron_y_pred_os, average='weighted', zero_division=0), precision_score(mlp_y_test_os, mlp_y_pred_os, average='weighted', zero_division=0)],
            [recall_score(svc_y_test_os, svc_y_pred_os, average='weighted'), recall_score(perceptron_y_test_os, perceptron_y_pred_os, average='weighted'), recall_score(mlp_y_test_os, mlp_y_pred_os, average='weighted')],
            [f1_score(svc_y_test_os, svc_y_pred_os, average='weighted'), f1_score(perceptron_y_test_os, perceptron_y_pred_os, average='weighted'), f1_score(mlp_y_test_os, mlp_y_pred_os, average='weighted')]
       ]
title = "Scores obtained using Oversampling"
plotComparisons(data, title)

# %%
data = [
            [accuracy_score(svc_y_test_us, svc_y_pred_us), accuracy_score(perceptron_y_test_us, perceptron_y_pred_us), accuracy_score(mlp_y_test_us, mlp_y_pred_us)],
            [precision_score(svc_y_test_us, svc_y_pred_us, average='weighted', zero_division=0), precision_score(perceptron_y_test_us, perceptron_y_pred_us, average='weighted', zero_division=0), precision_score(mlp_y_test_us, mlp_y_pred_us, average='weighted', zero_division=0)],
            [recall_score(svc_y_test_us, svc_y_pred_us, average='weighted'), recall_score(perceptron_y_test_us, perceptron_y_pred_us, average='weighted'), recall_score(mlp_y_test_us, mlp_y_pred_us, average='weighted')],
            [f1_score(svc_y_test_us, svc_y_pred_us, average='weighted'), f1_score(perceptron_y_test_us, perceptron_y_pred_us, average='weighted'), f1_score(mlp_y_test_us, mlp_y_pred_us, average='weighted')]
       ]
title = "Scores obtained using Undersampling"
plotComparisons(data, title)

# %%
def plotComparisons(data, title):
    X = np.arange(3)
    fig, axs = plt.subplots(1, 2, figsize=(15, 7.5))
    axs[0].bar(X + 0.2, data[0], color = '#3275a8', width = 0.2)
    axs[0].bar(X + 0.4, data[1], color = '#258f3c', width = 0.2)
    axs[0].bar(X + 0.6, data[2], color = '#d1682c', width = 0.2)
    axs[0].set_title("Training")
    
    X = np.arange(3)
    axs[1].bar(X + 0.2, data[3], color = '#9fd12c', width = 0.2)
    axs[1].bar(X + 0.4, data[4], color = '#3275a8', width = 0.2)
    axs[1].bar(X + 0.6, data[5], color = '#258f3c', width = 0.2)
    axs[1].set_title("Predicting")

    plt.xticks([0.25,1.25,2.25], ['SVM', 'Perceptron', 'Tuned MLP'])

    default_patch = mpatches.Patch(color='#3275a8', label='Train time Default')
    tunned_patch = mpatches.Patch(color='#258f3c', label='Train time Oversampling')
    tunned_patch_2 = mpatches.Patch(color='#d1682c', label='Train time Undersampling')
    plt.legend(handles=[default_patch, tunned_patch, tunned_patch_2], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    plt.xlabel("Algorithm")
    plt.ylabel("Time")
    print()

data = [
            [float(svc_train_time_default), float(perceptron_train_time_default), float(mlp_train_time_default)],
            [float(svc_train_time_os), float(perceptron_train_time_os), float(mlp_train_time_os)],
            [float(svc_train_time_us), float(perceptron_train_time_us), float(mlp_train_time_us)],
            [float(svc_predict_time_default), float(perceptron_predict_time_default), float(mlp_predict_time_default)],
            [float(svc_predict_time_os), float(perceptron_predict_time_os), float(mlp_predict_time_os)],
            [float(svc_predict_time_us), float(perceptron_predict_time_us), float(mlp_predict_time_us)],
       ]
title = "Scores obtained using Undersampling"
plotComparisons(data, title)

# %%
def plotComparisons(data, title):
    X = np.arange(2)
    fig, axs = plt.subplots(1, 3, figsize=(15, 7.5))
    axs[0].bar(X + 0.2, data[0], color = '#3275a8', width = 0.2)
    axs[0].bar(X + 0.4, data[1], color = '#258f3c', width = 0.2, tick_label=['Train', 'Predict'])
    axs[0].bar(X + 0.6, data[2], color = '#d1682c', width = 0.2)
    axs[0].set_title("Default")
    axs[0].set_ylabel('Time (s)')
    
    plt.xticks([0.4,1.4], ['Train', 'Predict'])
    
    X = np.arange(2)
    axs[1].bar(X + 0.2, data[3], color = '#3275a8', width = 0.2)
    axs[1].bar(X + 0.4, data[4], color = '#258f3c', width = 0.2, tick_label=['Train', 'Predict'])
    axs[1].bar(X + 0.6, data[5], color = '#d1682c', width = 0.2)
    axs[1].set_title("Oversampling")
    axs[1].set_ylabel('Time (s)')

    X = np.arange(2)
    axs[2].bar(X + 0.2, data[6], color = '#3275a8', width = 0.2)
    axs[2].bar(X + 0.4, data[7], color = '#258f3c', width = 0.2, tick_label=['Train', 'Predict'])
    axs[2].bar(X + 0.6, data[8], color = '#d1682c', width = 0.2)
    axs[2].set_title("Undersampling")
    axs[2].set_ylabel('Time (s)')

    default_patch = mpatches.Patch(color='#3275a8', label='SVM')
    tunned_patch = mpatches.Patch(color='#258f3c', label='Perceptron')
    tunned_patch_2 = mpatches.Patch(color='#d1682c', label='Tuned MLP')
    plt.legend(handles=[default_patch, tunned_patch, tunned_patch_2], bbox_to_anchor=(1.05, 1), loc='upper left', borderaxespad=0.)

    print()

data = [
            [float(svc_train_time_default), float(svc_predict_time_default)],
            [float(perceptron_train_time_default), float(perceptron_predict_time_default)],
            [float(mlp_train_time_default), float(mlp_predict_time_default)],
            [float(svc_train_time_os), float(svc_predict_time_os)],
            [float(perceptron_train_time_os), float(perceptron_predict_time_os)],
            [float(mlp_train_time_os), float(mlp_predict_time_os)],
            [float(svc_train_time_us), float(svc_predict_time_us)],
            [float(perceptron_train_time_us), float(perceptron_predict_time_us)],
            [float(mlp_train_time_us), float(mlp_predict_time_us)]
       ]
title = "Scores obtained using Undersampling"
plotComparisons(data, title)

# %% [markdown]
# Above are the graphs of training and predict running times for each of the algorithms.

# %% [markdown]
# ## Conclusions

# %% [markdown]
# We concluded that data processing, coupled with an adequate algorithm, is the most important factor for good prediction results in a problem such as this one.
# In our case, the Support Vector Machine Algorithm was the one that gave the best results in general.
# We enjoyed tweaking the processing, algorithms and parameters and verifying the results.
# Unfortunately, those tweaks didn’t give results that matched our expectations.
# We think that with more than just the under 4 thousand tweets of the given dataset we could achieve tremendously better results, especially in task B, which was unbalanced.
